# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("pokemon.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.6+ KB

# %%
data.corr()
# Out:
#                    #        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# #           1.000000  0.097712  0.102664  0.094691  0.089199  0.085596
# HP          0.097712  1.000000  0.422386  0.239622  0.362380  0.378718
# Attack      0.102664  0.422386  1.000000  0.438687  0.396362  0.263990
# Defense     0.094691  0.239622  0.438687  1.000000  0.223549  0.510747
# Sp. Atk     0.089199  0.362380  0.396362  0.223549  1.000000  0.506121
# Sp. Def     0.085596  0.378718  0.263990  0.510747  0.506121  1.000000
# Speed       0.012181  0.175952  0.381240  0.015227  0.473018  0.259133
# Generation  0.983428  0.058683  0.051451  0.042419  0.036437  0.028486
# Legendary   0.154336  0.273620  0.345408  0.246377  0.448907  0.363937
#
#                Speed  Generation  Legendary
# #           0.012181    0.983428   0.154336
# HP          0.175952    0.058683   0.273620
# Attack      0.381240    0.051451   0.345408
# Defense     0.015227    0.042419   0.246377
# ...

# %%
f,ax = plt.subplots(figsize = (18,18))
sns.heatmap(data.corr(),annot = True,linewidths = 0.5,fmt = '.1f',ax=ax)
plt.show()

# %%
data.Speed.plot(kind  = 'line',color = 'g',label = "Speed",linewidth = 1,alpha = 0.5,grid = True,linestyle = ':')
data.Defense.plot(color = 'r',label = 'Defence',linewidth = 1, grid = True,alpha = 0.5,linestyle = "-.")
plt.legend(loc = "upper right")
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('line plot')
plt.show()

# %%
data.plot(kind = 'scatter',x = 'Attack',y = 'Defense',color='r',grid=True,alpha=0.5,figsize = (12,12))
plt.xlabel('Attack')
plt.ylabel('Defense')
plt.title('attack vs defense scatter plt')
plt.show()

# %%
data.Speed.plot(kind = 'hist',bins=50,figsize = (8,8))
plt.show()

# %%
plt.clf()

# %%
data=pd.read_csv('pokemon.csv')

# %%
series = data['Defense']
print(type(series))
dataframe = data[['Defense']]
print(type(dataframe))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
x = data['Defense']>200
data[x]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 230  231       Shuckle    Bug    Rock  20      10      230       10      230
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 230      5           2      False
# 333     50           3      False

# %%
x = data['Defense']>200
y = data['Attack']>100
data[np.logical_and(x,y)]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 333     50           3      False

# %%
data[x & y]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 333     50           3      False

# %%
lis = ['car','box','dog']
for inx,value in enumerate(lis):
    print(inx ,":",value)
print(' ')
# Out:
# 0 : car
# 1 : box
# 2 : dog

# %%
for index,value in data[['Attack']][0:10].iterrows():
    print(index,':',value)
# Out:
# 0 : Attack    49
# Name: 0, dtype: int64
# 1 : Attack    62
# Name: 1, dtype: int64
# 2 : Attack    82
# Name: 2, dtype: int64
# 3 : Attack    100
# Name: 3, dtype: int64
# 4 : Attack    52
# Name: 4, dtype: int64
# 5 : Attack    64
# Name: 5, dtype: int64
# 6 : Attack    84
# Name: 6, dtype: int64
# 7 : Attack    130
# Name: 7, dtype: int64
# 8 : Attack    104
# Name: 8, dtype: int64
# 9 : Attack    48
# Name: 9, dtype: int64

# %%
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
def tuple_ex():
    t = (1,2,3)
    return t
a,b,c = tuple_ex()
print(a,b,c)
# Out:
# 1 2 3

# %%
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %%
def square():
    def addvar():
        x=2
        y=3
        z = x+y
        return z
    return addvar()**2
print(square())
# Out:
# 25

# %%
square = lambda x : x**2
print(square(4))
tot = lambda x,y,z:x+y+z
print(tot(1,5,9))
# Out:
# 16
# 15

# %%
numberlist =[1,2,3]
y = map(lambda x:x**2,numberlist)
print(list(y))
# Out:
# [1, 4, 9]

# %%
name = "monisha"
it = iter(name)
print(next(it))
print(next(it))
print(*it)
# Out:
# m
# o
# n i s h a

# %%
list1 = [1,23,45]
list2 = [2,5,7]
ziplist = zip(list1,list2)
print(ziplist)
z_list = list(ziplist)
print(z_list)
print(*z_list)
# Out:
# ...
# [(1, 2), (23, 5), (45, 7)]
# (1, 2) (23, 5) (45, 7)

# %%
unzip = zip(*z_list)
unlist1,unlist2 = list(unzip)
print(unlist1)
print(unlist2)
print(type(unlist2))
# Out:
# (1, 23, 45)
# (2, 5, 7)
# <class 'tuple'>

# %%
num1 = [1,2,3]
num2 = [i+1 for i in num1]
print(num2)
# Out:
# [2, 3, 4]

# %%
num1 = [5,10,15]
num2 = [i**2 if i==10 else i-5 if i<7 else i+5 for i in num1]
print(num2)
# Out:
# [0, 100, 20]

# %%
threshold = sum(data.Speed)/len(data.Speed)
#print(threshold)
data["speed_level"] = ["high" if i>threshold else "low" for i in data.Speed]
#data[:10,["Speed","speed_level"]]
data.loc[:10,["speed_level","Speed"]]
# Out:
#    speed_level  Speed
# 0          low     45
# 1          low     60
# 2         high     80
# 3         high     80
# 4          low     65
# 5         high     80
# 6         high    100
# 7         high    100
# 8         high    100
# 9          low     43
# 10         low     58

# %%
data = pd.read_csv("pokemon.csv")

# %%
data.head(5)
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data.tail()
# Out:
#        #            Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  796         Diancie     Rock  Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock  Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic  Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic   Dark  80     160       60      170
# 799  800       Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
data.shape
# Out:
# (800, 12)

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-6208d269f320> in <module>
# ----> 1 data.info()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in info(self, verbose, buf, max_cols, memory_usage, null_counts)
#    2481                 _non_verbose_repr()
#    2482             else:
# -> 2483                 _verbose_repr()
#    2484
#    2485         counts = self.get_dtype_counts()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _verbose_repr()
#    2439             tmpl = "{count}{dtype}"
#    2440             if show_counts:
# -> 2441                 counts = self.count()
#    2442                 if len(cols) != len(counts):  # pragma: no cover
#    2443                     raise AssertionError(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in count(self, axis, level, numeric_only)
# ...

# %%
print(data['Type 1'].value_counts(dropna = False))
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Ghost        32
# Dragon       32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
data.boxplot(column = "Attack",by='Legendary')

# %%
data_new = data.head()
print(data_new)
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
melted = pd.melt(frame = data_new,id_vars='Name',value_vars = ['Attack','Defense'])
melted
# Out:
#             Name variable  value
# 0      Bulbasaur   Attack     49
# 1        Ivysaur   Attack     62
# 2       Venusaur   Attack     82
# 3  Mega Venusaur   Attack    100
# 4     Charmander   Attack     52
# 5      Bulbasaur  Defense     49
# 6        Ivysaur  Defense     63
# 7       Venusaur  Defense     83
# 8  Mega Venusaur  Defense    123
# 9     Charmander  Defense     43

# %%
melted.pivot(index = "Name",columns = "variable",values='value')
# Out:
# variable       Attack  Defense
# Name
# Bulbasaur          49       49
# Charmander         52       43
# Ivysaur            62       63
# Mega Venusaur     100      123
# Venusaur           82       83

# %%
data1 = data.head()
data2 = data.tail()
conc_data_row = pd.concat([data1,data2],ignore_index = True,axis = 0)
conc_data_row
# Out:
#      #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1       Bulbasaur    Grass  Poison  45      49       49       65
# 1    2         Ivysaur    Grass  Poison  60      62       63       80
# 2    3        Venusaur    Grass  Poison  80      82       83      100
# 3    4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4    5      Charmander     Fire     NaN  39      52       43       60
# 5  796         Diancie     Rock   Fairy  50     100      150      100
# 6  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 7  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 8  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 9  800       Volcanion     Fire   Water  80     110      120      130
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# ...

# %%
data1 = data['Attack'].head()
data2 = data['Defense'].head()
condata12 = pd.concat([data1,data2],axis=1)
(condata12)
# Out:
# RangeIndex(start=0, stop=5, step=1)
#    Attack  Defense
# 0      49       49
# 1      62       63
# 2      82       83
# 3     100      123
# 4      52       43

# %%
data.dtypes
# Out:
# #                int64
# Name            object
# Type 1          object
# Type 2        category
# HP               int64
# Attack           int64
# Defense          int64
# Sp. Atk          int64
# Sp. Def          int64
# Speed            int64
# Generation       int64
# Legendary         bool
# dtype: object

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null category
# Type 2        414 non-null category
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), category(2), int64(8), object(1)
# memory usage: 60.2+ KB

# %%
print(data['Type 2'].value_counts(dropna = False))
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ice          14
# Water        14
# Ghost        14
# Rock         14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
data1 = data
data1['Type 2'].dropna(inplace = True)

# %%
#assert 1==1

# %%
assert data1['Type 2'].notnull().all()

# %%
data = pd.read_csv("pokemon.csv")

# %%
country = ['Spain','France']
population = ['11','12']
list_label = ['country','population']
list_col = [country,population]
zipped = dict(zip(list_label,list_col))
zipped
df = pd.DataFrame(zipped)
df
# Out:
#   country population
# 0   Spain         11
# 1  France         12

# %%
df['capital']=['madrid','Paris']
df
# Out:
#   country population capital
# 0   Spain         11  madrid
# 1  France         12   Paris

# %%
df['income'] = 0
df
# Out:
#   country population capital  income
# 0   Spain         11  madrid       0
# 1  France         12   Paris       0

# %%
data1 = data[['Attack','Defense','Speed']]
data1.plot()

# %%
data1 = data.loc[:,['Attack','Defense','Speed']]
data1.plot()

# %%
data1.plot(subplots=True)
plt.show()

# %%
data1.plot(kind = 'scatter',x = 'Attack',y='Defense')

# %%
data1.plot(kind = 'hist',y='Defense' , bins = 50,range =(0,250),normed = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py:1344: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   n, bins, patches = ax.hist(y, bins=bins, bottom=bottom, **kwds)

# %%
fig,axes = plt.subplots(nrows =2,ncols =1)
data1.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250),normed = True,ax = axes[0])
data1.plot(kind = 'hist',y='Defense',bins=50,range=(0,250),normed = True,ax=axes[1],cumulative = True)
plt.savefig('graph.png')
plt.show()

# %%
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
time_list = ['1992-02-17','1997-10-04']
print(type(time_list[0]))
# Out:
# <class 'str'>

# %%
datetime_obj = pd.to_datetime(time_list)
print(type(datetime_obj))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
import warnings
warnings.filterwarnings("ignore")
data2= data.head()
time_list = ['1996-01-17','1996-02-18','1996-03-19','1996-04-20','1996-05-21']
datetime_obj = pd.to_datetime(time_list)
data2['Date'] = datetime_obj
data2
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary       Date
# 0     45           1      False 1996-01-17
# 1     60           1      False 1996-02-18
# 2     80           1      False 1996-03-19
# 3     80           1      False 1996-04-20
# 4     65           1      False 1996-05-21

# %%
data2 =data2.set_index('Date')
data2
# Out:
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# Date
# 1996-01-17  1      Bulbasaur  Grass  Poison  45      49       49       65
# 1996-02-18  2        Ivysaur  Grass  Poison  60      62       63       80
# 1996-03-19  3       Venusaur  Grass  Poison  80      82       83      100
# 1996-04-20  4  Mega Venusaur  Grass  Poison  80     100      123      122
# 1996-05-21  5     Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# Date
# 1996-01-17       65     45           1      False
# 1996-02-18       80     60           1      False
# 1996-03-19      100     80           1      False
# 1996-04-20      120     80           1      False
# 1996-05-21       50     65           1      False

# %%
print(data2.loc["1996-02-18"])
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1996-02-18 00:00:00, dtype: object

# %%
data2.loc["1996-02-18":"1996-04-20"]
# Out:
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# Date
# 1996-02-18  2        Ivysaur  Grass  Poison  60      62       63       80
# 1996-03-19  3       Venusaur  Grass  Poison  80      82       83      100
# 1996-04-20  4  Mega Venusaur  Grass  Poison  80     100      123      122
#
#             Sp. Def  Speed  Generation  Legendary
# Date
# 1996-02-18       80     60           1      False
# 1996-03-19      100     80           1      False
# 1996-04-20      120     80           1      False

# %%
data2.resample('A').mean()
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Date
# 1996-12-31  3.0  60.8    69.0     72.2     85.4     83.0   66.0         1.0
#
#             Legendary
# Date
# 1996-12-31      False

# %%
data2.resample('M').mean()
# Out:
#             #  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Date
# 1996-01-31  1  45      49       49       65       65     45           1
# 1996-02-29  2  60      62       63       80       80     60           1
# 1996-03-31  3  80      82       83      100      100     80           1
# 1996-04-30  4  80     100      123      122      120     80           1
# 1996-05-31  5  39      52       43       60       50     65           1
#
#             Legendary
# Date
# 1996-01-31      False
# 1996-02-29      False
# 1996-03-31      False
# 1996-04-30      False
# 1996-05-31      False

# %%
import warnings
warnings.filterwarnings("ignore")
# In order to practice lets take head of pokemon data and add it a time list
data2 = data.head()
date_list = ["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
datetime_object = pd.to_datetime(date_list)
data2["date"] = datetime_object
# lets make date as index
data2= data2.set_index("date")
data2
# Out:
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# date
# 1992-01-10  1      Bulbasaur  Grass  Poison  45      49       49       65
# 1992-02-10  2        Ivysaur  Grass  Poison  60      62       63       80
# 1992-03-10  3       Venusaur  Grass  Poison  80      82       83      100
# 1993-03-15  4  Mega Venusaur  Grass  Poison  80     100      123      122
# 1993-03-16  5     Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# date
# 1992-01-10       65     45           1      False
# 1992-02-10       80     60           1      False
# 1992-03-10      100     80           1      False
# 1993-03-15      120     80           1      False
# 1993-03-16       50     65           1      False

# %%
data2.resample('A').mean()
# Out:
#               #         HP     Attack  Defense    Sp. Atk    Sp. Def  \
# date
# 1992-12-31  2.0  61.666667  64.333333     65.0  81.666667  81.666667
# 1993-12-31  4.5  59.500000  76.000000     83.0  91.000000  85.000000
#
#                 Speed  Generation  Legendary
# date
# 1992-12-31  61.666667         1.0      False
# 1993-12-31  72.500000         1.0      False

# %%
data2.resample('M').mean()
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# date
# 1992-01-31  1.0  45.0    49.0     49.0     65.0     65.0   45.0         1.0
# 1992-02-29  2.0  60.0    62.0     63.0     80.0     80.0   60.0         1.0
# 1992-03-31  3.0  80.0    82.0     83.0    100.0    100.0   80.0         1.0
# 1992-04-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-05-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-06-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-07-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-08-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-09-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-10-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-11-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# ...

# %%
data2.resample('M').first().interpolate("linear")
# Out:
#                    #           Name Type 1  Type 2    HP  Attack     Defense  \
# date
# 1992-01-31  1.000000      Bulbasaur  Grass  Poison  45.0    49.0   49.000000
# 1992-02-29  2.000000        Ivysaur  Grass  Poison  60.0    62.0   63.000000
# 1992-03-31  3.000000       Venusaur  Grass  Poison  80.0    82.0   83.000000
# 1992-04-30  3.083333            NaN    NaN     NaN  80.0    83.5   86.333333
# 1992-05-31  3.166667            NaN    NaN     NaN  80.0    85.0   89.666667
# 1992-06-30  3.250000            NaN    NaN     NaN  80.0    86.5   93.000000
# 1992-07-31  3.333333            NaN    NaN     NaN  80.0    88.0   96.333333
# 1992-08-31  3.416667            NaN    NaN     NaN  80.0    89.5   99.666667
# 1992-09-30  3.500000            NaN    NaN     NaN  80.0    91.0  103.000000
# 1992-10-31  3.583333            NaN    NaN     NaN  80.0    92.5  106.333333
# 1992-11-30  3.666667            NaN    NaN     NaN  80.0    94.0  109.666667
# ...

# %%
data2.resample('M').mean().interpolate('linear')
# Out:
#                 #         HP  Attack  Defense  Sp. Atk  Sp. Def   Speed  \
# date
# 1992-01-31  1.000  45.000000    49.0     49.0    65.00    65.00  45.000
# 1992-02-29  2.000  60.000000    62.0     63.0    80.00    80.00  60.000
# 1992-03-31  3.000  80.000000    82.0     83.0   100.00   100.00  80.000
# 1992-04-30  3.125  78.291667    81.5     83.0    99.25    98.75  79.375
# 1992-05-31  3.250  76.583333    81.0     83.0    98.50    97.50  78.750
# 1992-06-30  3.375  74.875000    80.5     83.0    97.75    96.25  78.125
# 1992-07-31  3.500  73.166667    80.0     83.0    97.00    95.00  77.500
# 1992-08-31  3.625  71.458333    79.5     83.0    96.25    93.75  76.875
# 1992-09-30  3.750  69.750000    79.0     83.0    95.50    92.50  76.250
# 1992-10-31  3.875  68.041667    78.5     83.0    94.75    91.25  75.625
# 1992-11-30  4.000  66.333333    78.0     83.0    94.00    90.00  75.000
# 1992-12-31  4.125  64.625000    77.5     83.0    93.25    88.75  74.375
# ...

# %%
data=pd.read_csv('pokemon.csv')

# %%
data = data.set_index('#')

# %%
data.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3       Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# 5     Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary
# #
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
# 5           1      False

# %%
data['HP'][1]
# Out:
# 45

# %%
data.HP[1]
# Out:
# 45

# %%
data.loc[1,['HP']]
# Out:
# HP    45
# Name: 1, dtype: object

# %%
data[["HP","Attack"]]
# Out:
#       HP  Attack
# #
# 1     45      49
# 2     60      62
# 3     80      82
# 4     80     100
# 5     39      52
# 6     58      64
# 7     78      84
# 8     78     130
# 9     78     104
# 10    44      48
# 11    59      63
# 12    79      83
# 13    79     103
# 14    45      30
# 15    50      20
# 16    60      45
# 17    40      35
# 18    45      25
# 19    65      90
# 20    65     150
# 21    40      45
# 22    63      60
# 23    83      80
# 24    83      80
# 25    30      56
# 26    55      81
# 27    40      60
# 28    65      90
# 29    35      60
# 30    60      85
# ..   ...     ...
# 771   95      65
# 772   78      92
# 773   67      58
# 774   50      50
# 775   45      50
# 776   68      75
# 777   90     100
# 778   57      80
# 779   43      70
# 780   85     110
# 781   49      66
# 782   44      66
# 783   54      66
# 784   59      66
# 785   65      90
# 786   55      85
# 787   75      95
# 788   85     100
# 789   55      69
# 790   95     117
# ...

# %%
data['HP']
# Out:
# #
# 1       45
# 2       60
# 3       80
# 4       80
# 5       39
# 6       58
# 7       78
# 8       78
# 9       78
# 10      44
# 11      59
# 12      79
# 13      79
# 14      45
# 15      50
# 16      60
# 17      40
# 18      45
# 19      65
# 20      65
# 21      40
# 22      63
# 23      83
# 24      83
# 25      30
# 26      55
# 27      40
# 28      65
# 29      35
# 30      60
#       ...
# 771     95
# 772     78
# 773     67
# 774     50
# 775     45
# 776     68
# 777     90
# 778     57
# 779     43
# 780     85
# 781     49
# 782     44
# 783     54
# 784     59
# 785     65
# 786     55
# 787     75
# 788     85
# 789     55
# 790     95
# 791     40
# 792     85
# 793    126
# 794    126
# 795    108
# 796     50
# 797     50
# 798     80
# 799     80
# 800     80
# Name: HP, Length: 800, dtype: int64

# %%
type(data['HP'])
# Out:
# pandas.core.series.Series

# %%
data[['HP']]
# Out:
#       HP
# #
# 1     45
# 2     60
# 3     80
# 4     80
# 5     39
# 6     58
# 7     78
# 8     78
# 9     78
# 10    44
# 11    59
# 12    79
# 13    79
# 14    45
# 15    50
# 16    60
# 17    40
# 18    45
# 19    65
# 20    65
# 21    40
# 22    63
# 23    83
# 24    83
# 25    30
# 26    55
# 27    40
# 28    65
# 29    35
# 30    60
# ..   ...
# 771   95
# 772   78
# 773   67
# 774   50
# 775   45
# 776   68
# 777   90
# 778   57
# 779   43
# 780   85
# 781   49
# 782   44
# 783   54
# 784   59
# 785   65
# 786   55
# 787   75
# 788   85
# 789   55
# 790   95
# 791   40
# 792   85
# 793  126
# 794  126
# 795  108
# 796   50
# 797   50
# 798   80
# 799   80
# 800   80
#
# [800 rows x 1 columns]

# %%
type(data[['HP']])
# Out:
# pandas.core.frame.DataFrame

# %%
data.loc[1:10,'HP':'Defense']
# Out:
#     HP  Attack  Defense
# #
# 1   45      49       49
# 2   60      62       63
# 3   80      82       83
# 4   80     100      123
# 5   39      52       43
# 6   58      64       58
# 7   78      84       78
# 8   78     130      111
# 9   78     104       78
# 10  44      48       65

# %%
data.loc[10:1:-1,'HP':'Defense']
# Out:
#     HP  Attack  Defense
# #
# 10  44      48       65
# 9   78     104       78
# 8   78     130      111
# 7   78      84       78
# 6   58      64       58
# 5   39      52       43
# 4   80     100      123
# 3   80      82       83
# 2   60      62       63
# 1   45      49       49

# %%
data.loc[1:10,"Speed":]
# Out:
#     Speed  Generation  Legendary
# #
# 1      45           1      False
# 2      60           1      False
# 3      80           1      False
# 4      80           1      False
# 5      65           1      False
# 6      80           1      False
# 7     100           1      False
# 8     100           1      False
# 9     100           1      False
# 10     43           1      False

# %%
boolean = data.HP>200
data[boolean]
# Out:
#         Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 122  Chansey  Normal    NaN  250       5        5       35      105     50
# 262  Blissey  Normal    NaN  255      10       10       75      135     55
#
#      Generation  Legendary
# #
# 122           1      False
# 262           2      False

# %%
f_filter = data.HP>150
s_filter = data.Speed>35
data[f_filter & s_filter]
# Out:
#           Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 122    Chansey  Normal    NaN  250       5        5       35      105     50
# 262    Blissey  Normal    NaN  255      10       10       75      135     55
# 352    Wailord   Water    NaN  170      90       45       90       45     60
# 656  Alomomola   Water    NaN  165      75       80       40       45     65
#
#      Generation  Legendary
# #
# 122           1      False
# 262           2      False
# 352           3      False
# 656           5      False

# %%
type(data.HP[data.Speed>50])
# Out:
# pandas.core.series.Series

# %%
def div(n):
    return n/2
data.HP.apply(div).head()
# Out:
# #
# 1    22.5
# 2    30.0
# 3    40.0
# 4    40.0
# 5    19.5
# Name: HP, dtype: float64

# %%
data.HP.apply(lambda n:n/2)
# Out:
# #
# 1      22.5
# 2      30.0
# 3      40.0
# 4      40.0
# 5      19.5
# 6      29.0
# 7      39.0
# 8      39.0
# 9      39.0
# 10     22.0
# 11     29.5
# 12     39.5
# 13     39.5
# 14     22.5
# 15     25.0
# 16     30.0
# 17     20.0
# 18     22.5
# 19     32.5
# 20     32.5
# 21     20.0
# 22     31.5
# 23     41.5
# 24     41.5
# 25     15.0
# 26     27.5
# 27     20.0
# 28     32.5
# 29     17.5
# 30     30.0
#        ...
# 771    47.5
# 772    39.0
# 773    33.5
# 774    25.0
# 775    22.5
# 776    34.0
# 777    45.0
# 778    28.5
# 779    21.5
# 780    42.5
# 781    24.5
# 782    22.0
# 783    27.0
# 784    29.5
# 785    32.5
# 786    27.5
# 787    37.5
# 788    42.5
# 789    27.5
# 790    47.5
# 791    20.0
# 792    42.5
# 793    63.0
# 794    63.0
# 795    54.0
# 796    25.0
# 797    25.0
# 798    40.0
# 799    40.0
# 800    40.0
# Name: HP, Length: 800, dtype: float64

# %%
data['Total_power'] = data.Attack + data.Defense
data.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3       Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# 5     Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary  Total_power
# #
# 1           1      False           98
# 2           1      False          125
# 3           1      False          165
# 4           1      False          223
# 5           1      False           95

# %%
print(data.index.name)
# Out:
# #

# %%
data.index.name = 'index_name'
data.head()
# Out:
#                      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# index_name
# 1               Bulbasaur  Grass  Poison  45      49       49       65
# 2                 Ivysaur  Grass  Poison  60      62       63       80
# 3                Venusaur  Grass  Poison  80      82       83      100
# 4           Mega Venusaur  Grass  Poison  80     100      123      122
# 5              Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary  Total_power
# index_name
# 1                65     45           1      False           98
# 2                80     60           1      False          125
# 3               100     80           1      False          165
# 4               120     80           1      False          223
# 5                50     65           1      False           95

# %%
data3 = data.copy()
data3.index = range(100,900)
data3.head()
# Out:
#               Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 100      Bulbasaur  Grass  Poison  45      49       49       65       65
# 101        Ivysaur  Grass  Poison  60      62       63       80       80
# 102       Venusaur  Grass  Poison  80      82       83      100      100
# 103  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 104     Charmander   Fire     NaN  39      52       43       60       50
#
#      Speed  Generation  Legendary  Total_power
# 100     45           1      False           98
# 101     60           1      False          125
# 102     80           1      False          165
# 103     80           1      False          223
# 104     65           1      False           95

# %%
data = pd.read_csv("pokemon.csv")
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data1 = data.set_index(['Type 1','Type 2'])
data1.head(100)
# Out:
#                     #              Name   HP  Attack  Defense  Sp. Atk  \
# Type 1   Type 2
# Grass    Poison     1         Bulbasaur   45      49       49       65
#          Poison     2           Ivysaur   60      62       63       80
#          Poison     3          Venusaur   80      82       83      100
#          Poison     4     Mega Venusaur   80     100      123      122
# Fire     NaN        5        Charmander   39      52       43       60
#          NaN        6        Charmeleon   58      64       58       80
#          Flying     7         Charizard   78      84       78      109
#          Dragon     8  Mega Charizard X   78     130      111      130
#          Flying     9  Mega Charizard Y   78     104       78      159
# Water    NaN       10          Squirtle   44      48       65       50
#          NaN       11         Wartortle   59      63       80       65
#          NaN       12         Blastoise   79      83      100       85
# ...

# %%
data1.loc['Water','Ice']
# Out:
#                  #      Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1 Type 2
# Water  Ice      95   Dewgong   90      70       80       70       95     70
#        Ice      99  Cloyster   50      95      180       85       45     70
#        Ice     143    Lapras  130      85       80       85       95     60
#
#                Generation  Legendary
# Type 1 Type 2
# Water  Ice              1      False
#        Ice              1      False
#        Ice              1      False

# %%
dic = {"treatment":["A","A","B","B"],"gender":["F","M","F","M"],"response":[10,45,5,9],"age":[15,4,72,65]}
data = pd.DataFrame(dic)
data
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
data.pivot(index = 'treatment',columns = 'gender',values = 'age')
# Out:
# gender      F   M
# treatment
# A          15   4
# B          72  65

# %%
df1 = data.set_index(['treatment','gender'])
df1
# Out:
#                   response  age
# treatment gender
# A         F             10   15
#           M             45    4
# B         F              5   72
#           M              9   65

# %%
df1.unstack(level = 0)
# Out:
#           response    age
# treatment        A  B   A   B
# gender
# F               10  5  15  72
# M               45  9   4  65

# %%
df1.unstack(level = 1)
# Out:
#           response     age
# gender           F   M   F   M
# treatment
# A               10  45  15   4
# B                5   9  72  65

# %%
df2 = df1.swaplevel(0,1)
df2
# Out:
#                   response  age
# gender treatment
# F      A                10   15
# M      A                45    4
# F      B                 5   72
# M      B                 9   65

# %%
data
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
pd.melt(data,id_vars = 'treatment',value_vars = ['response','age'])
# Out:
#   treatment  variable  value
# 0         A  response     10
# 1         A  response     45
# 2         B  response      5
# 3         B  response      9
# 4         A       age     15
# 5         A       age      4
# 6         B       age     72
# 7         B       age     65

# %%
data
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
data.groupby('treatment').mean()
# Out:
#            response   age
# treatment
# A              27.5   9.5
# B               7.0  68.5

# %%
data.groupby('treatment').age.max()
# Out:
# treatment
# A    15
# B    72
# Name: age, dtype: int64

# %%
data.groupby('treatment')[['age','response']].mean()
# Out:
#             age  response
# treatment
# A           9.5      27.5
# B          68.5       7.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
# treatment    4 non-null object
# gender       4 non-null object
# response     4 non-null int64
# age          4 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 208.0+ bytes
